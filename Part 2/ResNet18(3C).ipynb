# %%
from tensorflow.keras import backend as K
K.clear_session()
# !pip install rarfile
import os
import pandas as pd
import gdown
import rarfile
import shutil
from PIL import Image

#https://drive.google.com/file/d/1O0_qr4yHPDp_O36wS59mVvyYiX3c9pYk/view?usp=drive_link



url = 'https://drive.google.com/uc?id=1O0_qr4yHPDp_O36wS59mVvyYiX3c9pYk'
output_rar = '/content/SDR.rar'
gdown.download(url, output_rar, quiet=False)
# Extract the RAR file
with rarfile.RarFile(output_rar, 'r') as rar_ref:
    rar_ref.extractall('/content')
# Path to the extracted dataset folder
dataset_folder = '/content/SDR'
# Out:
# Collecting rarfile
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.2
# Downloading...
# From (original): https://drive.google.com/uc?id=1O0_qr4yHPDp_O36wS59mVvyYiX3c9pYk
# From (redirected): https://drive.google.com/uc?id=1O0_qr4yHPDp_O36wS59mVvyYiX3c9pYk&confirm=t&uuid=f947f1ee-9113-4efd-8e0d-a3ea43cdb03f
# To: /content/SDR.rar
# 100%|██████████| 231M/231M [00:04<00:00, 50.7MB/s]

# %% [markdown]
# # ResNet-18 using SWISH

# %%
#ResNet-18 A refined ResNet18 architecture with swish SERENA2023
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from sklearn.model_selection import KFold
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Add, GlobalAveragePooling2D, Flatten, Dense

# Define the Swish activation function
def swish(x):
    return x * tf.keras.backend.sigmoid(x)
# Define the CNN architecture
input_shape = (224, 224, 3)
num_classes = 3  # Change this to the number of classes in your problem

# Input
inputs = Input(shape=input_shape)

# Initial convolution layer
x = Conv2D(64, (7, 7), strides=(2, 2), padding='same')(inputs)
x = BatchNormalization()(x)
x = Activation(swish)(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

# Residual blocks
num_blocks = [2, 2, 2, 2]  # Number of residual blocks in each stage

for stage in range(4):
    for block in range(num_blocks[stage]):
        # First residual block in each stage has a stride of 2
        if stage > 0 and block == 0:
            strides = (2, 2)
        else:
            strides = (1, 1)

        # Convolutional block
        y = Conv2D(64 * 2**stage, (3, 3), strides=strides, padding='same')(x)
        y = BatchNormalization()(y)
        y = Activation(swish)(y)

        # Convolutional block
        y = Conv2D(64 * 2**stage, (3, 3), padding='same')(y)
        y = BatchNormalization()(y)

        # Shortcut connection
        if strides == (2, 2) or x.shape[-1] != y.shape[-1]:
            x = Conv2D(64 * 2**stage, (1, 1), strides=strides, padding='same')(x)
            x = BatchNormalization()(x)

        # Add the shortcut to the main path
        x = Add()([x, y])
        x = Activation(swish)(x)

# Global average pooling and final dense layer
x = GlobalAveragePooling2D()(x)
outputs = Dense(num_classes, activation='softmax')(x)

# Create the ResNet-18 model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print a summary of the model architecture
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 112, 112,  │      9,472 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 112, 112,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 56, 56,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 56, 56,    │     36,928 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 56, 56,    │     36,928 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 56, 56,    │          0 │ max_pooling2d[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 56, 56,    │          0 │ add[0][0]         │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 56, 56,    │     36,928 │ activation_2[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │     36,928 │ activation_3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 56, 56,    │          0 │ activation_2[0][… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 56, 56,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 28, 28,    │     73,856 │ activation_4[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │      8,320 │ activation_4[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │    147,584 │ activation_5[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 28, 28,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 28, 28,    │    147,584 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 28, 28,    │    147,584 │ activation_7[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 28, 28,    │          0 │ activation_6[0][… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 28, 28,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 14, 14,    │    295,168 │ activation_8[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 14, 14,    │     33,024 │ activation_8[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 14, 14,    │    590,080 │ activation_9[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 14, 14,    │    590,080 │ activation_10[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 14, 14,    │    590,080 │ activation_11[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 14, 14,    │          0 │ activation_10[0]… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 14, 14,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 7, 7, 512) │  1,180,160 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 7, 7, 512) │    131,584 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 7, 7, 512) │  2,359,808 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 512) │          0 │ add_6[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 7, 7, 512) │  2,359,808 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 7, 7, 512) │  2,359,808 │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 7, 7, 512) │          0 │ activation_14[0]… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 7, 7, 512) │          0 │ add_7[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ activation_16[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │      1,539 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,192,451 (42.70 MB)
#  Trainable params: 11,182,851 (42.66 MB)
#  Non-trainable params: 9,600 (37.50 KB)

# %% [markdown]
# # **Fold#1** ResNet-18

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# Load and preprocess the images
data_dir = '/content/Gradding 3C/Train'
class_names = ['Healthy', 'Mild-to-Moderate', 'Severe-to-Proleferative' ]
img_size = (224, 224)
batch_size = 32
epochs = 50
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Create the data generator for training set
train_data_generator = datagen.flow_from_directory(data_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=True, subset='training')

# Create the data generator for validation set
validation_data_generator = datagen.flow_from_directory(data_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=True, subset='validation')

# Assuming the model is already defined before compiling
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define the ModelCheckpoint callback to save best weights based on validation accuracy
# Define the ModelCheckpoint callback to save best weights based on validation accuracy
best_weights_path = '/content/Split/Save/best_model.keras'
checkpoint = ModelCheckpoint(best_weights_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Train the model and get the training history
history = model.fit(train_data_generator, epochs=epochs, validation_data=validation_data_generator, verbose=1, callbacks=[checkpoint])

# Plot train and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Train and Validation Loss')
plt.show()

# Plot train and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Train and Validation Accuracy')
plt.show()
# Out:
# Found 2674 images belonging to 3 classes.
# Found 666 images belonging to 3 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.6739 - loss: 1.0125
# Epoch 1: val_accuracy improved from -inf to 0.37387, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 68s 350ms/step - accuracy: 0.6744 - loss: 1.0098 - val_accuracy: 0.3739 - val_loss: 1.2626
# Epoch 2/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.7149 - loss: 0.6360
# Epoch 2: val_accuracy did not improve from 0.37387
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 150ms/step - accuracy: 0.7151 - loss: 0.6360 - val_accuracy: 0.3739 - val_loss: 1.4308
# Epoch 3/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7442 - loss: 0.6260
# Epoch 3: val_accuracy did not improve from 0.37387
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.7443 - loss: 0.6259 - val_accuracy: 0.3739 - val_loss: 1.7345
# Epoch 4/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7565 - loss: 0.5826
# Epoch 4: val_accuracy improved from 0.37387 to 0.37538, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.7565 - loss: 0.5826 - val_accuracy: 0.3754 - val_loss: 1.1837
# Epoch 5/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7536 - loss: 0.5997
# Epoch 5: val_accuracy improved from 0.37538 to 0.54655, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.7535 - loss: 0.5997 - val_accuracy: 0.5465 - val_loss: 1.3561
# Epoch 6/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7644 - loss: 0.5543
# Epoch 6: val_accuracy improved from 0.54655 to 0.73574, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - accuracy: 0.7643 - loss: 0.5547 - val_accuracy: 0.7357 - val_loss: 0.6260
# Epoch 7/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7748 - loss: 0.5810
# Epoch 7: val_accuracy improved from 0.73574 to 0.75075, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.7747 - loss: 0.5810 - val_accuracy: 0.7508 - val_loss: 0.5911
# Epoch 8/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7656 - loss: 0.5678
# Epoch 8: val_accuracy did not improve from 0.75075
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.7656 - loss: 0.5679 - val_accuracy: 0.7252 - val_loss: 0.6059
# Epoch 9/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7713 - loss: 0.5655
# Epoch 9: val_accuracy improved from 0.75075 to 0.78078, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.7713 - loss: 0.5656 - val_accuracy: 0.7808 - val_loss: 0.5409
# Epoch 10/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7597 - loss: 0.5726
# Epoch 10: val_accuracy did not improve from 0.78078
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step - accuracy: 0.7598 - loss: 0.5724 - val_accuracy: 0.7688 - val_loss: 0.5712
# Epoch 11/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7801 - loss: 0.5414
# Epoch 11: val_accuracy did not improve from 0.78078
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 149ms/step - accuracy: 0.7800 - loss: 0.5416 - val_accuracy: 0.7718 - val_loss: 0.5673
# Epoch 12/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7699 - loss: 0.5537
# Epoch 12: val_accuracy did not improve from 0.78078
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.7699 - loss: 0.5536 - val_accuracy: 0.7643 - val_loss: 0.5768
# Epoch 13/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7856 - loss: 0.5276
# Epoch 13: val_accuracy did not improve from 0.78078
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.7855 - loss: 0.5279 - val_accuracy: 0.7312 - val_loss: 0.5702
# Epoch 14/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7859 - loss: 0.5291
# Epoch 14: val_accuracy did not improve from 0.78078
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.7858 - loss: 0.5293 - val_accuracy: 0.7793 - val_loss: 0.5706
# Epoch 15/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.7757 - loss: 0.5244
# Epoch 15: val_accuracy improved from 0.78078 to 0.79129, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.7756 - loss: 0.5246 - val_accuracy: 0.7913 - val_loss: 0.4999
# Epoch 16/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.7822 - loss: 0.5217
# Epoch 16: val_accuracy did not improve from 0.79129
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - accuracy: 0.7822 - loss: 0.5219 - val_accuracy: 0.7643 - val_loss: 0.6025
# Epoch 17/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.7791 - loss: 0.5432
# Epoch 17: val_accuracy did not improve from 0.79129
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 149ms/step - accuracy: 0.7791 - loss: 0.5430 - val_accuracy: 0.7853 - val_loss: 0.5244
# Epoch 18/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7949 - loss: 0.5048
# Epoch 18: val_accuracy did not improve from 0.79129
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.7947 - loss: 0.5051 - val_accuracy: 0.7838 - val_loss: 0.6126
# Epoch 19/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.7849 - loss: 0.5145
# Epoch 19: val_accuracy did not improve from 0.79129
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - accuracy: 0.7848 - loss: 0.5147 - val_accuracy: 0.7583 - val_loss: 0.6021
# Epoch 20/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7853 - loss: 0.5260
# Epoch 20: val_accuracy did not improve from 0.79129
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.7853 - loss: 0.5259 - val_accuracy: 0.7853 - val_loss: 0.5388
# Epoch 21/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7739 - loss: 0.5063
# Epoch 21: val_accuracy did not improve from 0.79129
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - accuracy: 0.7740 - loss: 0.5064 - val_accuracy: 0.7733 - val_loss: 0.5681
# Epoch 22/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7817 - loss: 0.5128
# Epoch 22: val_accuracy did not improve from 0.79129
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 154ms/step - accuracy: 0.7818 - loss: 0.5127 - val_accuracy: 0.7763 - val_loss: 0.5613
# Epoch 23/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7823 - loss: 0.5132
# Epoch 23: val_accuracy did not improve from 0.79129
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 14s 161ms/step - accuracy: 0.7824 - loss: 0.5131 - val_accuracy: 0.7462 - val_loss: 0.6686
# Epoch 24/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7984 - loss: 0.4721
# Epoch 24: val_accuracy improved from 0.79129 to 0.79730, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.7983 - loss: 0.4723 - val_accuracy: 0.7973 - val_loss: 0.5009
# Epoch 25/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8097 - loss: 0.4532
# Epoch 25: val_accuracy did not improve from 0.79730
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - accuracy: 0.8096 - loss: 0.4534 - val_accuracy: 0.7763 - val_loss: 0.5657
# Epoch 26/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.7974 - loss: 0.4571
# Epoch 26: val_accuracy did not improve from 0.79730
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 154ms/step - accuracy: 0.7973 - loss: 0.4574 - val_accuracy: 0.7718 - val_loss: 0.6054
# Epoch 27/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7980 - loss: 0.4825
# Epoch 27: val_accuracy did not improve from 0.79730
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 152ms/step - accuracy: 0.7981 - loss: 0.4824 - val_accuracy: 0.7688 - val_loss: 0.6119
# Epoch 28/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8096 - loss: 0.4303
# Epoch 28: val_accuracy did not improve from 0.79730
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 151ms/step - accuracy: 0.8095 - loss: 0.4306 - val_accuracy: 0.7583 - val_loss: 0.6029
# Epoch 29/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8176 - loss: 0.4287
# Epoch 29: val_accuracy did not improve from 0.79730
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.8176 - loss: 0.4288 - val_accuracy: 0.7643 - val_loss: 0.5437
# Epoch 30/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8394 - loss: 0.3923
# Epoch 30: val_accuracy did not improve from 0.79730
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step - accuracy: 0.8392 - loss: 0.3927 - val_accuracy: 0.7733 - val_loss: 0.6322
# Epoch 31/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8306 - loss: 0.3935
# Epoch 31: val_accuracy did not improve from 0.79730
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 149ms/step - accuracy: 0.8306 - loss: 0.3936 - val_accuracy: 0.7973 - val_loss: 0.5276
# Epoch 32/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8293 - loss: 0.3854
# Epoch 32: val_accuracy improved from 0.79730 to 0.80781, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.8293 - loss: 0.3854 - val_accuracy: 0.8078 - val_loss: 0.5058
# Epoch 33/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8470 - loss: 0.3590
# Epoch 33: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step - accuracy: 0.8471 - loss: 0.3590 - val_accuracy: 0.7748 - val_loss: 0.5725
# Epoch 34/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8689 - loss: 0.3154
# Epoch 34: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.8687 - loss: 0.3158 - val_accuracy: 0.7658 - val_loss: 0.5712
# Epoch 35/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8802 - loss: 0.2965
# Epoch 35: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.8800 - loss: 0.2967 - val_accuracy: 0.7733 - val_loss: 0.5713
# Epoch 36/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8770 - loss: 0.2779
# Epoch 36: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step - accuracy: 0.8769 - loss: 0.2779 - val_accuracy: 0.7447 - val_loss: 0.7199
# Epoch 37/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8984 - loss: 0.2493
# Epoch 37: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 152ms/step - accuracy: 0.8983 - loss: 0.2495 - val_accuracy: 0.7838 - val_loss: 0.6746
# Epoch 38/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9294 - loss: 0.1893
# Epoch 38: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 150ms/step - accuracy: 0.9292 - loss: 0.1897 - val_accuracy: 0.7883 - val_loss: 0.5925
# Epoch 39/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9333 - loss: 0.1716
# Epoch 39: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - accuracy: 0.9332 - loss: 0.1718 - val_accuracy: 0.7943 - val_loss: 0.8120
# Epoch 40/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9397 - loss: 0.1453
# Epoch 40: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 149ms/step - accuracy: 0.9398 - loss: 0.1454 - val_accuracy: 0.8003 - val_loss: 0.6960
# Epoch 41/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9432 - loss: 0.1322
# Epoch 41: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 21s 150ms/step - accuracy: 0.9431 - loss: 0.1324 - val_accuracy: 0.8018 - val_loss: 0.9348
# Epoch 42/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9520 - loss: 0.1265
# Epoch 42: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 149ms/step - accuracy: 0.9520 - loss: 0.1266 - val_accuracy: 0.7793 - val_loss: 0.9721
# Epoch 43/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9677 - loss: 0.1030
# Epoch 43: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.9676 - loss: 0.1031 - val_accuracy: 0.7477 - val_loss: 0.9659
# Epoch 44/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9544 - loss: 0.1300
# Epoch 44: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 149ms/step - accuracy: 0.9545 - loss: 0.1299 - val_accuracy: 0.7868 - val_loss: 0.9046
# Epoch 45/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9639 - loss: 0.0950
# Epoch 45: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 151ms/step - accuracy: 0.9640 - loss: 0.0949 - val_accuracy: 0.8078 - val_loss: 1.0895
# Epoch 46/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9807 - loss: 0.0562
# Epoch 46: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - accuracy: 0.9806 - loss: 0.0563 - val_accuracy: 0.7688 - val_loss: 1.0079
# Epoch 47/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9652 - loss: 0.1077
# Epoch 47: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9652 - loss: 0.1075 - val_accuracy: 0.7883 - val_loss: 0.8446
# Epoch 48/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9795 - loss: 0.0648
# Epoch 48: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.9795 - loss: 0.0650 - val_accuracy: 0.7853 - val_loss: 1.0024
# Epoch 49/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9851 - loss: 0.0569
# Epoch 49: val_accuracy did not improve from 0.80781
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.9851 - loss: 0.0568 - val_accuracy: 0.7913 - val_loss: 0.9947
# Epoch 50/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9914 - loss: 0.0354
# Epoch 50: val_accuracy improved from 0.80781 to 0.81081, saving model to /content/Split/Save/best_model.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.9913 - loss: 0.0354 - val_accuracy: 0.8108 - val_loss: 1.1086

# %% [markdown]
# # Fold#1 Test ResNet-18

# %%
import os
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load the saved best weights
best_weights_path = '/content/Split/Save/best_model.keras'
model.load_weights(best_weights_path)

# Define the dataset directory
TestSet = '/content/Gradding 3C/Test'

# Create an ImageDataGenerator for test data
datagen = ImageDataGenerator(rescale=1.0/255)  # You can add other preprocessing steps here

test_data_generator = datagen.flow_from_directory(
    TestSet,
    target_size=img_size,  # Set your target image size (e.g., (224, 224))
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Do not shuffle the test data
)

# Get true labels and predicted labels
y_true = test_data_generator.classes
y_pred = np.argmax(model.predict(test_data_generator), axis=1)

# Calculate evaluation metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1-score:", f1)

# Calculate and display the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Found 838 images belonging to 3 classes.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step
# Test Accuracy: 0.7852028639618138
# Test Precision: 0.782262673980785
# Test Recall: 0.7852028639618138
# Test F1-score: 0.7642993279749478
# Confusion Matrix:
# [[361  33   1]
#  [ 31 267  15]
#  [  5  95  30]]
