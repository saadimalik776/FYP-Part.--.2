# %%
from tensorflow.keras import backend as K
K.clear_session()
# !pip install rarfile
import os
import pandas as pd
import gdown
import rarfile
import shutil
from PIL import Image




url = 'https://drive.google.com/uc?id=1tKIQZr4UUV-Ybz6rRQNhnqHDi1yQ2Ib5'
output_rar = '/content/SDR.rar'
gdown.download(url, output_rar, quiet=False)
# Extract the RAR file
with rarfile.RarFile(output_rar, 'r') as rar_ref:
    rar_ref.extractall('/content')
# Path to the extracted dataset folder
dataset_folder = '/content/SDR'
# Out:
# Collecting rarfile
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.2
# Downloading...
# From (original): https://drive.google.com/uc?id=1tKIQZr4UUV-Ybz6rRQNhnqHDi1yQ2Ib5
# From (redirected): https://drive.google.com/uc?id=1tKIQZr4UUV-Ybz6rRQNhnqHDi1yQ2Ib5&confirm=t&uuid=2cc055a2-d7ab-4468-943b-4a539f744b84
# To: /content/SDR.rar
# 100%|██████████| 221M/221M [00:01<00:00, 128MB/s]

# %%
import os
import shutil
import numpy as np

# Define paths
base_dir = "/content/Augmented"
train_dir = "/content/SDS/Train"
val_dir = "/content/SDS/Validation"

# Create train and validation directories
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

# Define class names
class_names = ['Class0', 'Class1', 'Class2', 'Class3', 'Class4']

# Split data (80% Train, 20% Validation)
for class_name in class_names:
    class_path = os.path.join(base_dir, class_name)
    images = os.listdir(class_path)
    np.random.shuffle(images)

    split_idx = int(len(images) * 0.8)
    train_images = images[:split_idx]
    val_images = images[split_idx:]

    # Create subdirectories
    os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(val_dir, class_name), exist_ok=True)

    # Move images
    for img in train_images:
        shutil.move(os.path.join(class_path, img), os.path.join(train_dir, class_name, img))

    for img in val_images:
        shutil.move(os.path.join(class_path, img), os.path.join(val_dir, class_name, img))

print("Data split completed: 80% Train, 20% Validation.")
# Out:
# Data split completed: 80% Train, 20% Validation.

# %% [markdown]
# # ResNet-18 using SWISH

# %%
#ResNet-18 A refined ResNet18 architecture with swish SERENA2023
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from sklearn.model_selection import KFold
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Add, GlobalAveragePooling2D, Flatten, Dense

# Define the Swish activation function
def swish(x):
    return x * tf.keras.backend.sigmoid(x)
# Define the CNN architecture
input_shape = (224, 224, 3)
num_classes = 5  # Change this to the number of classes in your problem

# Input
inputs = Input(shape=input_shape)

# Initial convolution layer
x = Conv2D(64, (7, 7), strides=(2, 2), padding='same')(inputs)
x = BatchNormalization()(x)
x = Activation(swish)(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

# Residual blocks
num_blocks = [2, 2, 2, 2]  # Number of residual blocks in each stage

for stage in range(4):
    for block in range(num_blocks[stage]):
        # First residual block in each stage has a stride of 2
        if stage > 0 and block == 0:
            strides = (2, 2)
        else:
            strides = (1, 1)

        # Convolutional block
        y = Conv2D(64 * 2**stage, (3, 3), strides=strides, padding='same')(x)
        y = BatchNormalization()(y)
        y = Activation(swish)(y)

        # Convolutional block
        y = Conv2D(64 * 2**stage, (3, 3), padding='same')(y)
        y = BatchNormalization()(y)

        # Shortcut connection
        if strides == (2, 2) or x.shape[-1] != y.shape[-1]:
            x = Conv2D(64 * 2**stage, (1, 1), strides=strides, padding='same')(x)
            x = BatchNormalization()(x)

        # Add the shortcut to the main path
        x = Add()([x, y])
        x = Activation(swish)(x)

# Global average pooling and final dense layer
x = GlobalAveragePooling2D()(x)
outputs = Dense(num_classes, activation='softmax')(x)

# Create the ResNet-18 model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print a summary of the model architecture
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 112, 112, 64)   │          9,472 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 112, 112, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 112, 112, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 56, 56, 64)     │              0 │ activation[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 56, 56, 64)     │         36,928 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 56, 56, 64)     │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 56, 56, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 56, 56, 64)     │         36,928 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 56, 56, 64)     │            256 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 56, 56, 64)     │              0 │ max_pooling2d[0][0],   │
# │                           │                        │                │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 56, 56, 64)     │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 56, 56, 64)     │         36,928 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 56, 56, 64)     │            256 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 56, 56, 64)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 56, 56, 64)     │         36,928 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 56, 56, 64)     │            256 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 56, 56, 64)     │              0 │ activation_2[0][0],    │
# │                           │                        │                │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 56, 56, 64)     │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 28, 28, 128)    │         73,856 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 28, 28, 128)    │            512 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 28, 28, 128)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 28, 28, 128)    │          8,320 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 28, 28, 128)    │        147,584 │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 28, 28, 128)    │            512 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 28, 28, 128)    │            512 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 28, 28, 128)    │              0 │ batch_normalization_7… │
# │                           │                        │                │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 28, 28, 128)    │              0 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 28, 28, 128)    │        147,584 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 28, 28, 128)    │            512 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 28, 28, 128)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 28, 28, 128)    │        147,584 │ activation_7[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 28, 28, 128)    │            512 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 28, 28, 128)    │              0 │ activation_6[0][0],    │
# │                           │                        │                │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 28, 28, 128)    │              0 │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 14, 14, 256)    │        295,168 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 14, 14, 256)    │          1,024 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 14, 14, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 14, 14, 256)    │         33,024 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 14, 14, 256)    │        590,080 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 14, 14, 256)    │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 14, 14, 256)    │          1,024 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 14, 14, 256)    │              0 │ batch_normalization_1… │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 14, 14, 256)    │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 14, 14, 256)    │        590,080 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 14, 14, 256)    │          1,024 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 14, 14, 256)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 14, 14, 256)    │        590,080 │ activation_11[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 14, 14, 256)    │          1,024 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 14, 14, 256)    │              0 │ activation_10[0][0],   │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 14, 14, 256)    │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 7, 7, 512)      │      1,180,160 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 7, 7, 512)      │          2,048 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 7, 7, 512)      │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 7, 7, 512)      │        131,584 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 7, 7, 512)      │      2,359,808 │ activation_13[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 7, 7, 512)      │          2,048 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 7, 7, 512)      │          2,048 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 7, 7, 512)      │              0 │ batch_normalization_1… │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 7, 7, 512)      │              0 │ add_6[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 7, 7, 512)      │      2,359,808 │ activation_14[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 7, 7, 512)      │          2,048 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 7, 7, 512)      │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 7, 7, 512)      │      2,359,808 │ activation_15[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 7, 7, 512)      │          2,048 │ conv2d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 7, 7, 512)      │              0 │ activation_14[0][0],   │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 7, 7, 512)      │              0 │ add_7[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 512)            │              0 │ activation_16[0][0]    │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 5)              │          2,565 │ global_average_poolin… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 11,193,477 (42.70 MB)
#  Trainable params: 11,183,877 (42.66 MB)
#  Non-trainable params: 9,600 (37.50 KB)

# %% [markdown]
# # **Fold#1** ResNet-18

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# Load and preprocess the images
data_dir = '/content/SDS/Train'
class_names = ['Class0', 'Class1', 'Class2', 'Class3', 'Class4' ]
img_size = (224, 224)
batch_size = 32
epochs = 60
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Create the data generator for training set
train_data_generator = datagen.flow_from_directory(data_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=True, subset='training')

# Create the data generator for validation set
validation_data_generator = datagen.flow_from_directory(data_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=True, subset='validation')

# Assuming the model is already defined before compiling
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define the ModelCheckpoint callback to save best weights based on validation accuracy
# Define the ModelCheckpoint callback to save best weights based on validation accuracy
best_weights_path = '/content/Split/Save/best_model.keras'
checkpoint = ModelCheckpoint(best_weights_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Train the model and get the training history
history = model.fit(train_data_generator, epochs=epochs, validation_data=validation_data_generator, verbose=1, callbacks=[checkpoint])

# Plot train and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Train and Validation Loss')
plt.show()

# Plot train and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Train and Validation Accuracy')
plt.show()
# Out:
# Found 6400 images belonging to 5 classes.
# Found 1600 images belonging to 5 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.3936 - loss: 1.5031
# Epoch 1: val_accuracy improved from -inf to 0.20000, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.3937 - loss: 1.5022 - val_accuracy: 0.2000 - val_loss: 2.2889
# Epoch 2/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4542 - loss: 1.1856
# Epoch 2: val_accuracy improved from 0.20000 to 0.28688, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 68s 142ms/step - accuracy: 0.4542 - loss: 1.1856 - val_accuracy: 0.2869 - val_loss: 1.5642
# Epoch 3/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4822 - loss: 1.1574
# Epoch 3: val_accuracy improved from 0.28688 to 0.45000, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 148ms/step - accuracy: 0.4822 - loss: 1.1574 - val_accuracy: 0.4500 - val_loss: 1.5519
# Epoch 4/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5071 - loss: 1.1115
# Epoch 4: val_accuracy did not improve from 0.45000
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 35s 174ms/step - accuracy: 0.5070 - loss: 1.1116 - val_accuracy: 0.4375 - val_loss: 1.6931
# Epoch 5/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5175 - loss: 1.1033
# Epoch 5: val_accuracy improved from 0.45000 to 0.48500, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 35s 146ms/step - accuracy: 0.5175 - loss: 1.1033 - val_accuracy: 0.4850 - val_loss: 2.0516
# Epoch 6/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5709 - loss: 1.0355
# Epoch 6: val_accuracy improved from 0.48500 to 0.53312, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 151ms/step - accuracy: 0.5709 - loss: 1.0354 - val_accuracy: 0.5331 - val_loss: 1.6267
# Epoch 7/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6163 - loss: 0.9210
# Epoch 7: val_accuracy did not improve from 0.53312
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.6162 - loss: 0.9211 - val_accuracy: 0.4881 - val_loss: 2.2849
# Epoch 8/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6482 - loss: 0.8724
# Epoch 8: val_accuracy did not improve from 0.53312
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.6482 - loss: 0.8724 - val_accuracy: 0.5156 - val_loss: 1.7744
# Epoch 9/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6729 - loss: 0.8027
# Epoch 9: val_accuracy did not improve from 0.53312
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 142ms/step - accuracy: 0.6729 - loss: 0.8027 - val_accuracy: 0.5331 - val_loss: 1.7012
# Epoch 10/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7129 - loss: 0.7351
# Epoch 10: val_accuracy improved from 0.53312 to 0.57687, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 146ms/step - accuracy: 0.7129 - loss: 0.7351 - val_accuracy: 0.5769 - val_loss: 1.1337
# Epoch 11/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7501 - loss: 0.6453
# Epoch 11: val_accuracy did not improve from 0.57687
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 143ms/step - accuracy: 0.7502 - loss: 0.6453 - val_accuracy: 0.5450 - val_loss: 1.8782
# Epoch 12/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8097 - loss: 0.5025
# Epoch 12: val_accuracy improved from 0.57687 to 0.62437, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 146ms/step - accuracy: 0.8097 - loss: 0.5026 - val_accuracy: 0.6244 - val_loss: 1.3736
# Epoch 13/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8507 - loss: 0.4043
# Epoch 13: val_accuracy did not improve from 0.62437
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 141ms/step - accuracy: 0.8506 - loss: 0.4044 - val_accuracy: 0.5519 - val_loss: 2.2828
# Epoch 14/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8783 - loss: 0.3111
# Epoch 14: val_accuracy improved from 0.62437 to 0.65625, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 146ms/step - accuracy: 0.8783 - loss: 0.3112 - val_accuracy: 0.6562 - val_loss: 1.4482
# Epoch 15/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9263 - loss: 0.2276
# Epoch 15: val_accuracy did not improve from 0.65625
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.9263 - loss: 0.2277 - val_accuracy: 0.5950 - val_loss: 1.5432
# Epoch 16/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9372 - loss: 0.1959
# Epoch 16: val_accuracy improved from 0.65625 to 0.66562, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 146ms/step - accuracy: 0.9372 - loss: 0.1959 - val_accuracy: 0.6656 - val_loss: 1.5693
# Epoch 17/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9554 - loss: 0.1311
# Epoch 17: val_accuracy did not improve from 0.66562
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.9554 - loss: 0.1312 - val_accuracy: 0.5781 - val_loss: 2.6181
# Epoch 18/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9722 - loss: 0.0891
# Epoch 18: val_accuracy improved from 0.66562 to 0.69813, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 151ms/step - accuracy: 0.9721 - loss: 0.0892 - val_accuracy: 0.6981 - val_loss: 1.5813
# Epoch 19/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9758 - loss: 0.0895
# Epoch 19: val_accuracy did not improve from 0.69813
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 142ms/step - accuracy: 0.9758 - loss: 0.0896 - val_accuracy: 0.6513 - val_loss: 2.2088
# Epoch 20/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9704 - loss: 0.0973
# Epoch 20: val_accuracy improved from 0.69813 to 0.71750, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 145ms/step - accuracy: 0.9704 - loss: 0.0973 - val_accuracy: 0.7175 - val_loss: 1.5398
# Epoch 21/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9836 - loss: 0.0608
# Epoch 21: val_accuracy did not improve from 0.71750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 146ms/step - accuracy: 0.9836 - loss: 0.0608 - val_accuracy: 0.6425 - val_loss: 1.9605
# Epoch 22/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9774 - loss: 0.0806
# Epoch 22: val_accuracy did not improve from 0.71750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - accuracy: 0.9774 - loss: 0.0806 - val_accuracy: 0.7094 - val_loss: 1.6508
# Epoch 23/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9805 - loss: 0.0671
# Epoch 23: val_accuracy did not improve from 0.71750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - accuracy: 0.9805 - loss: 0.0671 - val_accuracy: 0.7081 - val_loss: 1.6002
# Epoch 24/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9825 - loss: 0.0540
# Epoch 24: val_accuracy improved from 0.71750 to 0.72500, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 170ms/step - accuracy: 0.9825 - loss: 0.0540 - val_accuracy: 0.7250 - val_loss: 1.5976
# Epoch 25/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9886 - loss: 0.0405
# Epoch 25: val_accuracy did not improve from 0.72500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - accuracy: 0.9886 - loss: 0.0406 - val_accuracy: 0.7150 - val_loss: 2.0758
# Epoch 26/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9812 - loss: 0.0625
# Epoch 26: val_accuracy did not improve from 0.72500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 147ms/step - accuracy: 0.9812 - loss: 0.0625 - val_accuracy: 0.7200 - val_loss: 1.7460
# Epoch 27/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9751 - loss: 0.0730
# Epoch 27: val_accuracy did not improve from 0.72500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 145ms/step - accuracy: 0.9751 - loss: 0.0730 - val_accuracy: 0.6450 - val_loss: 2.8854
# Epoch 28/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9843 - loss: 0.0532
# Epoch 28: val_accuracy did not improve from 0.72500
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.9843 - loss: 0.0532 - val_accuracy: 0.7025 - val_loss: 1.6061
# Epoch 29/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9893 - loss: 0.0333
# Epoch 29: val_accuracy improved from 0.72500 to 0.72750, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 147ms/step - accuracy: 0.9893 - loss: 0.0333 - val_accuracy: 0.7275 - val_loss: 1.6840
# Epoch 30/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9886 - loss: 0.0368
# Epoch 30: val_accuracy did not improve from 0.72750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 142ms/step - accuracy: 0.9886 - loss: 0.0369 - val_accuracy: 0.6094 - val_loss: 3.3952
# Epoch 31/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9825 - loss: 0.0552
# Epoch 31: val_accuracy did not improve from 0.72750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 144ms/step - accuracy: 0.9825 - loss: 0.0553 - val_accuracy: 0.7050 - val_loss: 1.8498
# Epoch 32/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9841 - loss: 0.0521
# Epoch 32: val_accuracy did not improve from 0.72750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 147ms/step - accuracy: 0.9842 - loss: 0.0520 - val_accuracy: 0.7156 - val_loss: 2.1805
# Epoch 33/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9933 - loss: 0.0247
# Epoch 33: val_accuracy did not improve from 0.72750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - accuracy: 0.9932 - loss: 0.0247 - val_accuracy: 0.6762 - val_loss: 2.1259
# Epoch 34/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9881 - loss: 0.0294
# Epoch 34: val_accuracy did not improve from 0.72750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 142ms/step - accuracy: 0.9881 - loss: 0.0295 - val_accuracy: 0.5575 - val_loss: 4.6884
# Epoch 35/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9777 - loss: 0.0605
# Epoch 35: val_accuracy did not improve from 0.72750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 148ms/step - accuracy: 0.9777 - loss: 0.0605 - val_accuracy: 0.6712 - val_loss: 2.3027
# Epoch 36/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9876 - loss: 0.0378
# Epoch 36: val_accuracy did not improve from 0.72750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 142ms/step - accuracy: 0.9876 - loss: 0.0378 - val_accuracy: 0.6969 - val_loss: 2.0528
# Epoch 37/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9945 - loss: 0.0171
# Epoch 37: val_accuracy improved from 0.72750 to 0.74875, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 146ms/step - accuracy: 0.9944 - loss: 0.0171 - val_accuracy: 0.7487 - val_loss: 1.5546
# Epoch 38/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9903 - loss: 0.0285
# Epoch 38: val_accuracy did not improve from 0.74875
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 143ms/step - accuracy: 0.9903 - loss: 0.0285 - val_accuracy: 0.6388 - val_loss: 3.6297
# Epoch 39/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9783 - loss: 0.0620
# Epoch 39: val_accuracy did not improve from 0.74875
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 164ms/step - accuracy: 0.9783 - loss: 0.0620 - val_accuracy: 0.6812 - val_loss: 2.6666
# Epoch 40/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9931 - loss: 0.0215
# Epoch 40: val_accuracy improved from 0.74875 to 0.76750, saving model to /content/Split/Save/best_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 154ms/step - accuracy: 0.9931 - loss: 0.0215 - val_accuracy: 0.7675 - val_loss: 1.2780
# Epoch 41/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9898 - loss: 0.0220
# Epoch 41: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 147ms/step - accuracy: 0.9898 - loss: 0.0220 - val_accuracy: 0.7175 - val_loss: 2.1005
# Epoch 42/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9902 - loss: 0.0282
# Epoch 42: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.9902 - loss: 0.0282 - val_accuracy: 0.7256 - val_loss: 1.8444
# Epoch 43/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9896 - loss: 0.0318
# Epoch 43: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 144ms/step - accuracy: 0.9896 - loss: 0.0318 - val_accuracy: 0.7044 - val_loss: 2.3239
# Epoch 44/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9937 - loss: 0.0182
# Epoch 44: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 143ms/step - accuracy: 0.9937 - loss: 0.0183 - val_accuracy: 0.7325 - val_loss: 1.7559
# Epoch 45/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9875 - loss: 0.0314
# Epoch 45: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.9875 - loss: 0.0314 - val_accuracy: 0.7169 - val_loss: 2.0395
# Epoch 46/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9879 - loss: 0.0360
# Epoch 46: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.9879 - loss: 0.0360 - val_accuracy: 0.7131 - val_loss: 1.8979
# Epoch 47/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9925 - loss: 0.0238
# Epoch 47: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 145ms/step - accuracy: 0.9925 - loss: 0.0238 - val_accuracy: 0.6619 - val_loss: 2.9883
# Epoch 48/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9868 - loss: 0.0413
# Epoch 48: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 146ms/step - accuracy: 0.9868 - loss: 0.0412 - val_accuracy: 0.7138 - val_loss: 1.9655
# Epoch 49/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9977 - loss: 0.0081
# Epoch 49: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.9977 - loss: 0.0081 - val_accuracy: 0.7231 - val_loss: 2.3192
# Epoch 50/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9957 - loss: 0.0108
# Epoch 50: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 145ms/step - accuracy: 0.9957 - loss: 0.0109 - val_accuracy: 0.7412 - val_loss: 1.7614
# Epoch 51/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9941 - loss: 0.0175
# Epoch 51: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - accuracy: 0.9940 - loss: 0.0177 - val_accuracy: 0.5831 - val_loss: 4.4830
# Epoch 52/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9826 - loss: 0.0516
# Epoch 52: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 143ms/step - accuracy: 0.9826 - loss: 0.0516 - val_accuracy: 0.6700 - val_loss: 2.5707
# Epoch 53/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9859 - loss: 0.0372
# Epoch 53: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 148ms/step - accuracy: 0.9860 - loss: 0.0372 - val_accuracy: 0.7125 - val_loss: 1.9826
# Epoch 54/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9958 - loss: 0.0127
# Epoch 54: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 143ms/step - accuracy: 0.9958 - loss: 0.0127 - val_accuracy: 0.7306 - val_loss: 1.7760
# Epoch 55/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9956 - loss: 0.0148
# Epoch 55: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.9956 - loss: 0.0148 - val_accuracy: 0.7594 - val_loss: 1.7722
# Epoch 56/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9969 - loss: 0.0071
# Epoch 56: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - accuracy: 0.9969 - loss: 0.0071 - val_accuracy: 0.7163 - val_loss: 2.1840
# Epoch 57/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9975 - loss: 0.0059
# Epoch 57: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 145ms/step - accuracy: 0.9975 - loss: 0.0059 - val_accuracy: 0.7375 - val_loss: 2.0546
# Epoch 58/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9970 - loss: 0.0057
# Epoch 58: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - accuracy: 0.9970 - loss: 0.0057 - val_accuracy: 0.7356 - val_loss: 1.8854
# Epoch 59/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9909 - loss: 0.0235
# Epoch 59: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.9909 - loss: 0.0236 - val_accuracy: 0.6587 - val_loss: 3.3826
# Epoch 60/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9765 - loss: 0.0653
# Epoch 60: val_accuracy did not improve from 0.76750
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 143ms/step - accuracy: 0.9765 - loss: 0.0652 - val_accuracy: 0.7387 - val_loss: 1.5573

# %%
import os
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load the saved best weights
best_weights_path = '/content/Split/Save/best_model.keras'
model.load_weights(best_weights_path)

# Define the dataset directory
TestSet = '/content/SDS/Validation'

# Create an ImageDataGenerator for test data
datagen = ImageDataGenerator(rescale=1.0/255)  # You can add other preprocessing steps here

test_data_generator = datagen.flow_from_directory(
    TestSet,
    target_size=img_size,  # Set your target image size (e.g., (224, 224))
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Do not shuffle the test data
)

# Get true labels and predicted labels
y_true = test_data_generator.classes
y_pred = np.argmax(model.predict(test_data_generator), axis=1)

# Calculate evaluation metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1-score:", f1)

# Calculate and display the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Found 2000 images belonging to 5 classes.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step
# Test Accuracy: 0.7845
# Test Precision: 0.7833016071985259
# Test Recall: 0.7845
# Test F1-score: 0.7802282736369553
# Confusion Matrix:
# [[390   4   6   0   0]
#  [ 15 343  25   4  13]
#  [ 22  81 230  38  29]
#  [  6  23  25 310  36]
#  [  3  32  31  38 296]]
